# %%
import numpy as np
import pandas as pd

# %%
hist = pd.read_csv("History.csv")
hist.set_index("Ticket",inplace=True)
hist.head(10)
# Out:
#                      Open Time  Type  Size        Item        Price  \
# Ticket
# 226629935  2020.09.21 20:37:58   buy  0.02   de30eur-e  12594.20000
# 226672345  2020.09.22 21:58:32   buy  0.20    xauusd-e   1905.90700
# 226707531  2020.09.23 15:27:06   buy  0.25    audcad-e      0.94908
# 226712369  2020.09.23 19:15:11   buy  0.15    xauusd-e   1865.06400
# 226798519  2020.09.25 19:46:36   buy  1.00    eurusd-e      1.16244
# 226800003  2020.09.25 21:40:37   buy  0.10   hk33hkd-e  23124.60000
# 226800801  2020.09.25 22:55:20   buy  0.90    audjpy-e     74.28500
# 226827062  2020.09.28 00:56:16   buy  1.00    audusd-e      0.70349
# 226838301  2020.09.28 15:48:30  sell  0.75    eurtry-e      9.13132
# 226839565  2020.09.28 16:49:47   buy  3.00  wheatusd-e      5.32500
#
#                 S / L       T / P           Close Time      Price.1  \
# Ticket
# 226629935  12571.0000  12620.5000  2020.09.21 21:05:31  12571.00000
# ...
