# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

# %%
DB = pd.read_excel("Base de datos.xlsx")
DB.head(5)
# Out:
#    Folio         ID Levantada por        Municipio       CP        Sector  \
# 0      1  208841844          IIEG      Tlaquepaque  45608.0      Comercio
# 1      2  208843594          IIEG      Guadalajara  44630.0  Construcción
# 2      3  208844050          IIEG  Puerto Vallarta  48333.0   Manufactura
# 3      5  208844264          IIEG      Guadalajara  44890.0      Comercio
# 4      7  208845188          IIEG  Lagos de Moreno  47420.0     Servicios
#
#                                 Giro rango_empleados Tamaño  tiempo_operacion  \
# 0                               Otro           0 a 5  Micro                20
# 1  Edificación de naves industriales           0 a 5  Micro                 5
# 2                          Impresión           0 a 5  Micro                11
# 3               Tiendas de celulares           0 a 5  Micro                 3
# 4         Reparación de electrónicos           0 a 5  Micro                 2
#
#    ...                           conocimiento_apoyo aumento_insumos  \
# 0  ...                                           No              No
# 1  ...                                           No              No
# 2  ...                                           Sí              Sí
# 3  ...                                           No              Sí
# 4  ...  He escuchado de él, pero no lo conozco bien              Sí
#
#                   aumento_precios escasez_insumos  aumento_tipocambio  \
# 0                       No aplica              Sí               No sé
# 1                       No aplica              Sí                  Sí
# 2  No, pero lo estoy considerando              No                  Sí
# 3                              Sí              No                  Sí
# 4                              Sí              Sí                  Sí
#
#   informado  lineamientos                                           acciones  \
# 0        Sí            No  Forzar a los gobernadores a seguir las indicac...
# 1        Sí            Sí  informacion clara y precisa para accesar a apo...
# 2        Sí            No  apoyos empresariales para cubrir sueldos duran...
# 3        Sí            Sí  Apoyos directos a la economía de la empresa, c...
# 4        Sí            Sí                                                NaN
#
#                                                 plan  \
# 0                                    no es necesario
# 1  Tratar de mantener la Calidad y eficiencia en ...
# 2  alentar al turismo a que nos visite para que m...
# 3  Evaluar primero si siguen operando, los riesgo...
# 4                                                NaN
#
#                                        oportunidades
# 0  si, menos competencia si otros cierran por fal...
# 1  el escenario es dificil puesto que en lo econó...
# 2                                                 no
# 3  Si, enfocar los esfuerzos en la comercializaci...
# 4                                                NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# # Paso 1: Quitar NAs' de códigos postales:

# %%
DB['CP'].count()
# Out:
# 1916

# %%
DB.count()
# Out:
# Folio                     1992
# ID                        1992
# Levantada por             1992
# Municipio                 1992
# CP                        1916
# Sector                    1992
# Giro                      1992
# rango_empleados           1992
# Tamaño                    1992
# tiempo_operacion          1992
# años_empresa              1992
# provedores                1992
# provedores_nacionales     1992
# ventas                    1992
# ventas_porcentaje         1992
# perdidas                  1992
# perdidas_porcentaje       1992
# capacidad                 1992
# cerrar                    1992
# cerrar_razon              1992
# despidos                  1992
# plantilla_porcentaje      1992
# pago_salarios             1992
# pago_impuestos            1992
# pago_creditos             1992
# pago_renta                1992
# pago_internet             1992
# pago_agua                 1992
# pago_luz                  1992
# pago_gas                  1992
# duracion                  1992
# capacidad_pago            1992
# acuerdo_laboral           1992
# pago_proporcion           1992
# trabajo_casa              1992
# trabajo_casa_motivo       1992
# credito                   1992
# capacidad_pago_credito    1992
# credito_prorroga          1992
# conocimiento_apoyo        1992
# aumento_insumos           1992
# aumento_precios           1992
# escasez_insumos           1992
# aumento_tipocambio        1992
# informado                 1992
# lineamientos              1992
# acciones                  1628
# plan                      1783
# oportunidades             1705
# dtype: int64

# %%
DB = DB.dropna(subset=['CP'])
DB = DB.reset_index()
DB
# Out:
#       index  Folio         ID Levantada por        Municipio       CP  \
# 0         0      1  208841844          IIEG      Tlaquepaque  45608.0
# 1         1      2  208843594          IIEG      Guadalajara  44630.0
# 2         2      3  208844050          IIEG  Puerto Vallarta  48333.0
# 3         3      5  208844264          IIEG      Guadalajara  44890.0
# 4         4      7  208845188          IIEG  Lagos de Moreno  47420.0
# ...     ...    ...        ...           ...              ...      ...
# 1911   1987   1951  209032456         CUCEA  Lagos de Moreno  48460.0
# 1912   1988   1955  209032595         CUCEA  Lagos de Moreno  47480.0
# 1913   1989   1961  209032863          IIEG      Guadalajara  44360.0
# 1914   1990   1963  209032983         CUCEA  Lagos de Moreno  47470.0
# 1915   1991   1987  209045096          IIEG      Guadalajara  44160.0
#
#             Sector                                      Giro rango_empleados  \
# 0         Comercio                                      Otro           0 a 5
# 1     Construcción         Edificación de naves industriales           0 a 5
# 2      Manufactura                                 Impresión           0 a 5
# 3         Comercio                      Tiendas de celulares           0 a 5
# 4        Servicios                Reparación de electrónicos           0 a 5
# ...            ...                                       ...             ...
# 1911      Comercio                           No especificado          6 a 10
# 1912  Construcción        Fabricación de productos de madera          6 a 10
# 1913      Comercio             Joyerías y tiendas de relojes          6 a 10
# 1914     Servicios                                  Escuelas          6 a 10
# 1915     Servicios  Inmobiliarias y agentes de bienes raíces          6 a 10
#
#      Tamaño  ...                           conocimiento_apoyo aumento_insumos  \
# 0     Micro  ...                                           No              No
# 1     Micro  ...                                           No              No
# 2     Micro  ...                                           Sí              Sí
# 3     Micro  ...                                           No              Sí
# 4     Micro  ...  He escuchado de él, pero no lo conozco bien              Sí
# ...     ...  ...                                          ...             ...
# 1911  Micro  ...  He escuchado de él, pero no lo conozco bien              No
# 1912  Micro  ...  He escuchado de él, pero no lo conozco bien              Sí
# 1913  Micro  ...                                           No              Sí
# 1914  Micro  ...                                           No              No
# 1915  Micro  ...  He escuchado de él, pero no lo conozco bien           No sé
#
#                      aumento_precios  escasez_insumos aumento_tipocambio  \
# 0                          No aplica               Sí              No sé
# 1                          No aplica               Sí                 Sí
# 2     No, pero lo estoy considerando               No                 Sí
# 3                                 Sí               No                 Sí
# 4                                 Sí               Sí                 Sí
# ...                              ...              ...                ...
# 1911                       No aplica               No                 No
# 1912                              Sí               Sí                 Sí
# 1913  No, pero lo estoy considerando               Sí                 Sí
# 1914                       No aplica               No                 No
# 1915                       No aplica               No              No sé
#
#       informado lineamientos  \
# 0            Sí           No
# 1            Sí           Sí
# 2            Sí           No
# 3            Sí           Sí
# 4            Sí           Sí
# ...         ...          ...
# 1911         Sí           Sí
# 1912         Sí           No
# 1913         Sí           Sí
# 1914         No           No
# 1915         Sí           No
#
#                                                acciones  \
# 0     Forzar a los gobernadores a seguir las indicac...
# 1     informacion clara y precisa para accesar a apo...
# 2     apoyos empresariales para cubrir sueldos duran...
# 3     Apoyos directos a la economía de la empresa, c...
# 4                                                   NaN
# ...                                                 ...
# 1911  Necesitamos apoyo para pago de sueldos a emple...
# 1912                    Apoyar más el trabajo informal
# 1913                             Dinero a fondo perdido
# 1914                                              No se
# 1915  Prórroga en pago de impuestos, energía y apoyo...
#
#                                                    plan  \
# 0                                       no es necesario
# 1     Tratar de mantener la Calidad y eficiencia en ...
# 2     alentar al turismo a que nos visite para que m...
# 3     Evaluar primero si siguen operando, los riesgo...
# 4                                                   NaN
# ...                                                 ...
# 1911                       Hacer visitas personalizadas
# 1912  Sinhemosnoptadl por poner en marcha varias for...
# 1913                                     Si publicidad
# 1914      La promoción de los grupos q se puedan abrir
# 1915  Identificar nuevas necesidades del mercado y m...
#
#                                           oportunidades
# 0     si, menos competencia si otros cierran por fal...
# 1     el escenario es dificil puesto que en lo econó...
# 2                                                    no
# 3     Si, enfocar los esfuerzos en la comercializaci...
# 4                                                   NaN
# ...                                                 ...
# 1911  No, primero necesitamos recuperarnos, luego pe...
# 1912                                                 No
# 1913                                                 No
# 1914  No, trabajamos sector salud y está siendo muy ...
# 1915  Posiblemente haya mucha oferta de créditos hip...
#
# [1916 rows x 50 columns]

# %%
DB.count()
# Out:
# index                     1916
# Folio                     1916
# ID                        1916
# Levantada por             1916
# Municipio                 1916
# CP                        1916
# Sector                    1916
# Giro                      1916
# rango_empleados           1916
# Tamaño                    1916
# tiempo_operacion          1916
# años_empresa              1916
# provedores                1916
# provedores_nacionales     1916
# ventas                    1916
# ventas_porcentaje         1916
# perdidas                  1916
# perdidas_porcentaje       1916
# capacidad                 1916
# cerrar                    1916
# cerrar_razon              1916
# despidos                  1916
# plantilla_porcentaje      1916
# pago_salarios             1916
# pago_impuestos            1916
# pago_creditos             1916
# pago_renta                1916
# pago_internet             1916
# pago_agua                 1916
# pago_luz                  1916
# pago_gas                  1916
# duracion                  1916
# capacidad_pago            1916
# acuerdo_laboral           1916
# pago_proporcion           1916
# trabajo_casa              1916
# trabajo_casa_motivo       1916
# credito                   1916
# capacidad_pago_credito    1916
# credito_prorroga          1916
# conocimiento_apoyo        1916
# aumento_insumos           1916
# aumento_precios           1916
# escasez_insumos           1916
# aumento_tipocambio        1916
# informado                 1916
# lineamientos              1916
# acciones                  1576
# plan                      1720
# oportunidades             1647
# dtype: int64

# %% [markdown]
# ***
# # Paso 2: quitar valores atípicos

# %%
for i in range(len(DB)):
    if DB['provedores_nacionales'][i]>100:
        DB.loc[i,'provedores_nacionales'] = np.nan
        
    if DB['ventas_porcentaje'][i]>100:
        DB.loc[i,'ventas_porcentaje'] = np.nan
        
    if DB['perdidas_porcentaje'][i]>100:
        DB.loc[i,'perdidas_porcentaje'] = np.nan
        
    if DB['capacidad'][i]>100:
        DB.loc[i,'capacidad'] = np.nan
        
    if DB['plantilla_porcentaje'][i]>100:
        DB.loc[i,'plantilla_porcentaje'] = np.nan
        
    if DB['pago_impuestos'][i] == "No contesto":
        DB.loc[i,'pago_impuestos'] = np.nan
        
    if DB['pago_creditos'][i] == "No contesto":
        DB.loc[i,'pago_creditos'] = np.nan
        
    if DB['pago_renta'][i] == "No contesto":
        DB.loc[i,'pago_renta'] = np.nan
        
    if DB['pago_internet'][i] == "No contesto":
        DB.loc[i,'pago_internet'] = np.nan
        
    if DB['pago_agua'][i] == "No contesto":
        DB.loc[i,'pago_agua'] = np.nan
        
    if DB['pago_luz'][i] == "No contesto":
        DB.loc[i,'pago_luz'] = np.nan
        
    if DB['pago_gas'][i] == "No contesto":
        DB.loc[i,'pago_gas'] = np.nan
        
    if DB['pago_proporcion'][i]>120:
        DB.loc[i,'pago_proporcion'] = np.nan
        
    if DB['capacidad_pago_credito'][i] == "No contesto":
        DB.loc[i,'capacidad_pago_credito'] = np.nan
        
    if DB['credito_prorroga'][i] == "No contesto":
        DB.loc[i,'credito_prorroga'] = np.nan
    if DB['credito_prorroga'][i] == 998:
        DB.loc[i,'credito_prorroga'] = np.nan
    if DB['credito_prorroga'][i] == 999:
        DB.loc[i,'credito_prorroga'] = np.nan
        
    if DB['informado'][i] == "No contesto":
        DB.loc[i,'informado'] = np.nan
        
    if DB['lineamientos'][i] == "No contesto":
        DB.loc[i,'lineamientos'] = np.nan

# %%
DB
# Out:
#       index  Folio         ID Levantada por        Municipio       CP  \
# 0         0      1  208841844          IIEG      Tlaquepaque  45608.0
# 1         1      2  208843594          IIEG      Guadalajara  44630.0
# 2         2      3  208844050          IIEG  Puerto Vallarta  48333.0
# 3         3      5  208844264          IIEG      Guadalajara  44890.0
# 4         4      7  208845188          IIEG  Lagos de Moreno  47420.0
# ...     ...    ...        ...           ...              ...      ...
# 1911   1987   1951  209032456         CUCEA  Lagos de Moreno  48460.0
# 1912   1988   1955  209032595         CUCEA  Lagos de Moreno  47480.0
# 1913   1989   1961  209032863          IIEG      Guadalajara  44360.0
# 1914   1990   1963  209032983         CUCEA  Lagos de Moreno  47470.0
# 1915   1991   1987  209045096          IIEG      Guadalajara  44160.0
#
#             Sector                                      Giro rango_empleados  \
# 0         Comercio                                      Otro           0 a 5
# 1     Construcción         Edificación de naves industriales           0 a 5
# 2      Manufactura                                 Impresión           0 a 5
# 3         Comercio                      Tiendas de celulares           0 a 5
# 4        Servicios                Reparación de electrónicos           0 a 5
# ...            ...                                       ...             ...
# 1911      Comercio                           No especificado          6 a 10
# 1912  Construcción        Fabricación de productos de madera          6 a 10
# 1913      Comercio             Joyerías y tiendas de relojes          6 a 10
# 1914     Servicios                                  Escuelas          6 a 10
# 1915     Servicios  Inmobiliarias y agentes de bienes raíces          6 a 10
#
#      Tamaño  ...                           conocimiento_apoyo aumento_insumos  \
# 0     Micro  ...                                           No              No
# 1     Micro  ...                                           No              No
# 2     Micro  ...                                           Sí              Sí
# 3     Micro  ...                                           No              Sí
# 4     Micro  ...  He escuchado de él, pero no lo conozco bien              Sí
# ...     ...  ...                                          ...             ...
# 1911  Micro  ...  He escuchado de él, pero no lo conozco bien              No
# 1912  Micro  ...  He escuchado de él, pero no lo conozco bien              Sí
# 1913  Micro  ...                                           No              Sí
# 1914  Micro  ...                                           No              No
# 1915  Micro  ...  He escuchado de él, pero no lo conozco bien           No sé
#
#                      aumento_precios  escasez_insumos aumento_tipocambio  \
# 0                          No aplica               Sí              No sé
# 1                          No aplica               Sí                 Sí
# 2     No, pero lo estoy considerando               No                 Sí
# 3                                 Sí               No                 Sí
# 4                                 Sí               Sí                 Sí
# ...                              ...              ...                ...
# 1911                       No aplica               No                 No
# 1912                              Sí               Sí                 Sí
# 1913  No, pero lo estoy considerando               Sí                 Sí
# 1914                       No aplica               No                 No
# 1915                       No aplica               No              No sé
#
#       informado lineamientos  \
# 0            Sí           No
# 1            Sí           Sí
# 2            Sí           No
# 3            Sí           Sí
# 4            Sí           Sí
# ...         ...          ...
# 1911         Sí           Sí
# 1912         Sí           No
# 1913         Sí           Sí
# 1914         No           No
# 1915         Sí           No
#
#                                                acciones  \
# 0     Forzar a los gobernadores a seguir las indicac...
# 1     informacion clara y precisa para accesar a apo...
# 2     apoyos empresariales para cubrir sueldos duran...
# 3     Apoyos directos a la economía de la empresa, c...
# 4                                                   NaN
# ...                                                 ...
# 1911  Necesitamos apoyo para pago de sueldos a emple...
# 1912                    Apoyar más el trabajo informal
# 1913                             Dinero a fondo perdido
# 1914                                              No se
# 1915  Prórroga en pago de impuestos, energía y apoyo...
#
#                                                    plan  \
# 0                                       no es necesario
# 1     Tratar de mantener la Calidad y eficiencia en ...
# 2     alentar al turismo a que nos visite para que m...
# 3     Evaluar primero si siguen operando, los riesgo...
# 4                                                   NaN
# ...                                                 ...
# 1911                       Hacer visitas personalizadas
# 1912  Sinhemosnoptadl por poner en marcha varias for...
# 1913                                     Si publicidad
# 1914      La promoción de los grupos q se puedan abrir
# 1915  Identificar nuevas necesidades del mercado y m...
#
#                                           oportunidades
# 0     si, menos competencia si otros cierran por fal...
# 1     el escenario es dificil puesto que en lo econó...
# 2                                                    no
# 3     Si, enfocar los esfuerzos en la comercializaci...
# 4                                                   NaN
# ...                                                 ...
# 1911  No, primero necesitamos recuperarnos, luego pe...
# 1912                                                 No
# 1913                                                 No
# 1914  No, trabajamos sector salud y está siendo muy ...
# 1915  Posiblemente haya mucha oferta de créditos hip...
#
# [1916 rows x 50 columns]

# %%
DB.describe()
# Out:
#              index        Folio            ID            CP  tiempo_operacion  \
# count  1916.000000  1916.000000  1.916000e+03   1916.000000       1916.000000
# mean    992.578288  1001.425365  2.089636e+08  45546.110647         14.174843
# std     574.692982   578.073520  5.448574e+04   1548.626439         12.643049
# min       0.000000     1.000000  2.088418e+08  25122.000000          0.000000
# 25%     497.750000   497.750000  2.089254e+08  44600.000000          5.000000
# 50%     993.500000  1002.500000  2.089607e+08  45050.000000         10.000000
# 75%    1483.250000  1504.250000  2.090142e+08  45662.250000         20.000000
# max    1991.000000  1992.000000  2.090471e+08  59455.000000        118.000000
#
#        provedores_nacionales  ventas_porcentaje  perdidas_porcentaje  \
# count            1874.000000        1781.000000          1762.000000
# mean               86.945037          69.793936            62.672531
# std                21.722161          22.395969            25.421468
# min                 0.000000           0.000000             3.000000
# 25%                80.000000          50.000000            40.000000
# 50%               100.000000          70.000000            60.000000
# 75%               100.000000          90.000000            80.000000
# max               100.000000         100.000000           100.000000
#
#          capacidad  plantilla_porcentaje  pago_proporcion
# count  1885.000000           1138.000000      1267.000000
# mean     30.016976             52.653779        54.738753
# std      28.061498             29.366600        20.457109
# min       0.000000              0.000000         0.000000
# 25%       5.000000             30.000000        50.000000
# 50%      20.000000             50.000000        50.000000
# 75%      50.000000             80.000000        60.000000
# max     100.000000            100.000000       110.000000
